# %% [markdown]
# # Gerenciar pacotes

# %% [markdown]
# ## instalar pacotes via pip se necessário

# %%
# %pip install geobr

# %% [markdown]
# ## importar pacotes

# %%
import pandas as pd
import geopandas as gpd
from glob import glob
import os
import geobr

# %% [markdown]
# # Selecionar dados para importação

# %% [markdown]
# https://github.com/ipea/geobr

# %%
geobr.list_geobr()
# Out:
#                      Function                         geography        source  \
# 0                read_country                           Country          IBGE
# 1                 read_region                            Region          IBGE
# 2                  read_state                            States          IBGE
# 3            read_meso_region                       Meso region          IBGE
# 4           read_micro_region                      Micro region          IBGE
# 5    read_intermediate_region               Intermediate region          IBGE
# 6       read_immediate_region                  Immediate region          IBGE
# 7           read_municipality                      Municipality          IBGE
# 8         read_municipal_seat                Municipality seats          IBGE
# 9         read_weighting_area             Census weighting area          IBGE
# 10          read_census_tract                      Census tract          IBGE
# ...

# %%
municipios = geobr.read_municipality(code_muni="all",year=2025)
municipios.head()

# %%
#ajustar pasta de trabalho
diretorio = "C:/Users/larissa.valadao/OneDrive - IPHAN - Instituto do Patrimônio Histórico e Artístico Nacional/Documentos/arquivos_analise/dados"
#nome de saída do arquivo
path = "municipios_2025.shp"

municipios.to_file(os.path.join(diretorio,path))
