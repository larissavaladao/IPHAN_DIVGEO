# %% [markdown]
# # Gerenciar pacotes

# %% [markdown]
# ## instalar pacotes via pip se necessário

# %%
# %pip install <package name>
# %pip install -r requirements.txt

# %% [markdown]
# ## importar pacotes

# %%
import os
from glob import glob
import fiona
import geopandas as gpd
import pandas as pd
from shapely.ops import polygonize
from shapely.geometry import MultiPolygon
import requests
from pathlib import Path
from urllib.parse import urlparse

# %%
import geo_functions as gf

# %% [markdown]
# # Rodar scraper

# %%
import SEI_scraper 
SEI_scraper.scraper()

# %% [markdown]
# # Adicionar dados

# %% [markdown]
# ## copiar caminhos no prompt

# %%
# in_dir = str(input("Digite o caminho para o diretório de entrada: ")).replace("\\","/")
# out_dir = str(input("Digite o caminho para o diretório de saída: ")).replace("\\","/")
# projecao = str(input("Digite a projeção desejada. Caso queira usar o padrão digite: 0")).strip()
# if projecao == str(0):
#   projecao = None

# %% [markdown]
# ## definir caminhos fixos

# %%
in_dir =  r'C:\Users\larissa.valadao\Documents\GitHub\IPHAN_DIVGEO\1.Calcular_areas\downloads_teste'

# %%
#Digite o caminho para o diretório de entrada e sáida

out_dir = r"C:\Users\larissa.valadao\OneDrive - IPHAN - Instituto do Patrimônio Histórico e Artístico Nacional\Documentos\arquivos_analise\out"

# %% [markdown]
# # Aplicação das funções

# %%
# Chamar com o DataFrame de processos
gf.area_files_list(
    in_dir=in_dir,
    out_dir=out_dir
)

# %% [markdown]
# #
